# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavo-kulbaba0/pcd-aula03/blob/main/atividade_aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = (input("qual é o seu nome?" ))

v1 = float(input("valor 1 =" ))
v2 = float(input("valor 2 =" ))
v3 = float(input("valor 3 =" ))

media = (v1 + v2 + v3) / 3

print (f"olá {nome}, sua media é {media :.2f}")
# Out:
# qual é o seu nome?gus
# valor 1 =1
